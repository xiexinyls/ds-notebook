# %% [markdown]
# # R
#
# ```
# getwd()
# ls()
# rm(sobj)
# rm( list=ls() )
# ```
#
# ## Help
# ```
# help(funcname)
# example(funcname)
# help(packa­ge = "ggpl­ot2")
# ?funcname
# ```
#
# ## Console Commands
# run some script
# ```
# source("scriptname.R")
# ```
#
# list datasets
# ```
# data()
# ```
#
# ## Data type
# ```
# logical
# TRUE T
# FALSE F
# & &&
# | ||
# !
# xor(x,y)
# ```
#
# ### String
# ```
# ""
# ''
# ```
#
# ### Number
# ```
# NaN
# Inf
# ```
#
# `NA`
# represent "not available", function of vector with NA will give NA unless sepecify `na.rm = TRUE`, usually FALSE by default
# ```
# is.na()
# is.nan()
# ```
#
# "numeric", "logical"
#
# integer
# 1L
#
# ### enforce coersion
# ```
# class(x)
# as.logical(1)      => TRUE
# as.numeric()
# as.numeric("10.5") => 10.5
# as.character(100)  => "100"
# as.Date('1970-01-01')
# as.POSIXct()
# as.POSIXlt()
# strptime(timestr, '%B %d %Y %H %M')
# ```
#
# ## Vector and List
#
# Remember
#
# double bracket: return the its type
#
# single bracket: return the element type
#
# vector("numeric", length=10)
#
# vector with different type will be coerced to the strong type
# string>numeirc>logical
# c("1.2", TRUE, 1) => string
#
# v[1]
# v[1:10]
#
#
# ### List
#
# cannot use multiple index
# ```
# list(TRUE, c(1, 2), "hi" )
# l[[1]]
# ```
#
# ```
# x <- list(name1=1:5, name2='a')
# ```
#
# `['name']` returns list
#
# `[index]` returns list
#
# `[['name']]` returns elements
#
# Check if they are the same?
#
# ```
# identical()
# ```
#
# ### Attributes
#
# ```
# attributes(obj)
# name
# dimnames()
# str()
# summary()
# ```
#
# ### assignment
#
# ```
# x <- 10
# ```
#
# OR
#
# ```
# x = 10
# ```
#
# printing
#
# ```
# print(x)
# ```
#
#
# ## Numerical command
#
# generating
# c Combine arguments to a vector
# c(1, 2, 3)
# if arguments are in different types, "c" will transform them
# cbnd(a, b, c)
# rbnd(a, c, c)
#
# 5:9 9:5
# or
# seq(5,9)
# seq(5,9,0.5)
#
# rep(item,times)
#
# matrix(value, dim1, dim2)
# matrix(0, 5, 3)
# x <- 1:15
# matrix(x, 5, 3)
#
#
# reshaping
# x <- 1:6
# dim(x) <- c(3,2)
#
#
# Indexing
# starting from 1, left dimension runs fastest
# x = c(1, 2, 3)
# [] returns the same thing, list from a list, data frame from a data frame
# x[1]
# x[1] = 5
# x[c(1,3)]
# x[1:2] = 3
# automatically grow the vector
# x[4] = 6
# x = matrix(1,5,5)
# x[2,3]
# x[2,]
# x[,3]
# x[1:3,]
#
# x[-1:-2] get indexing except those specified
#
# x[1, , drop=FALSE]
#
# choose the non-missing value
# goodind = complete.cases(x)
#
# [[ ]] is used from a list or data frame, returns not necessarily a list or data frame
# $ refer by name with partial matching
#
#
# Naming
# use function "name" to assign names to index
# x = 1:3
# names(x) = c('first','second','third')
# x['first']
# x$first
#
#
# Factors grouping
# like label
# x = 'cat', 'cat', 'dog', 'horse'
# y = factor(x)
# y = factor(x, levels=c('dog', 'cat') )
# print(y) [y = 'cat', 'cat', 'dog', 'horse' with levels 'cat', 'dog', 'horse']
# to see the internal integer representation use
# as.integer(y) [1, 1, 2, 3]
# get only the levels
# levels(y)
#
#
#
# Calculating
# support vector calculation
# x = 1:3
# x = x+1 [2,3,4]
# y = 2:4
# z = x+y [3,5,7]
# C = matA %*% matB # matrix multiplication
# logical operation
# y>x [T,T,T]
#
#
#
# Function support vector
# sin(x)
# sum(x)
# sum(x, na.rm=TRUE)
# sort(x$var1)
# order(x$var1) order(x$var1, x$var2)
#
# Basic statitics
# length(x)
# mean(x)
# median(x)
# sd(x)
# head(x)
# tail(x)
#
# correlation test
# cor.test(x1, x2)
#
# lapply(df, func) # list apply, return a list
# sapply(df, func) # return a vector, if the output length is 1
# apply(matrix, dimind, func)
# mapply(func, list1, list2, ...)
# tapply(x, factor, func, simplify=TRUE) # apply func according to the factor
# split(x, factor) # split according to the factor
#
#
# Data Frames
# used to organize table data
# col1 = c(1, 2, 3)
# col2 = c(500, 200, 300)
# col3 = c('dog', 'cat', 'cow')
# df = data.frame( col1, col2, col3)
# df = data.frame(colname1<-col1, colname2<-col2)
# get the ith column
# x[[2]]
# but x[2] will only give you a column
# x['col1']
# x[1:5,'col1']
# dollar shorthand, partial match
# x$col1
# get the ith/ith-jth row
# df[,i]
# df[,i:j]
#
# adding new variable
# df$newvar = oldvar
#
# nrow(df)
# ncol(df)
# names(df)
#
# convert data frame to a matrix
# data.matrix(df)
#
# frame merging
# merge(x = dataframe1, y = dataframe2)
# it merges two data frames by column names
#
#
#
# Control Flow
# ```
# if() {
#
# } else {
#
# }
# if() {
#
# } else if() {
#
# } else {
#
# }
# ```
#
# ```
# for( i in seq_len(n) ) {
# 	print(i)
# }
# for( i in seq_along(x) ) {
# 	print(i)
# }
# ```
#
# ```
# i = 1
# while( (i<10) && (i>5) ) {
# 	i = i + 1
# }
# ```
#
# ```
# repeat {
# 	break
# 	if () {
# 		next
# 	}
# 	return
# }
# ```
#
#
# ### Function Call
# ```
# sum(arguments)
# sum(arguments, argument names=arguments)
# ```
#
# ### Function
#
# ```
# f <- function(...) {
# 	args = list(...)
# }
# ```
#
# ## Reading Files
#
# CSV
#
# ```
# read.csv('input.csv') only reads files with "," delimit
# read.table('input.csv', sep='\t', skip=1) only reads files with specified delimit, no header
# read.table('input.csv', sep='\t', header=TRUE)
# ```
#
# for large dataset
# ```
# initial <- read.table('input.csv', nrow=100)
# classes <- sapply(initial, class)
# read.table('input.csv', colClass=classes)
# ```
#
# readLines
# ```
# write.table
# ```
#
# ```
# conn = file('input')
# do some work with the "conn"
# close(conn)
# gzfile
# bzfile
# url
# x <- readLines(conn, 10)
# ```
#
# ```
# dget('')
# dput(data, file='')
# source('')
# dump(data, file='')
# ```
#
# # Modeling
#
# Simulation
#
# sampling
#
# ```
# sample(data, nsample)
# sample(data, nsample, replace=FALSE) # meaning allow repeat or not
# sample(data, nsample, prob=probdata )
# ```
#
# ```
# set.seed(1)
# ```
#
# distribution
#
# ```
# r random
# d pdf
# p cdf
# q quantile
# ```
#
# ```
# rbinom
# dbinom
# pbinom
# qbinom
# ```
#
# ```
# rnorm(n, mean=0, sd=1)
# dnorm
# pnorm(, mean=0, sd=1, log=FALSE, lower.tail=TRUE, log.p=FALSE)
# ```
#
# ```
# rpois
# ```
#
# How to get the samples many times?
#
# ```
# replicate(times, rnorm(n))
# ```
#
# ### data splitting
#
# ```
# trainind <- createDataPartition(data, p=0.8, list=FALSE)
# xtrain <- data[trainind,]
# xtest <- data[-trainind,]
# ```
#
# ### linear model
#
# ```
# model = lm( model formula )
# model = lm( model formula, data=x )
# model = lm( y ~ x )
# ```
#
#
#
# # Ploting
#
#
# barplot
# ```
# x = 1:3
# barplot(x)
# names(x) = c('one', 'two', 'three')
# barplot(x)
# ```
#
# plot
# ```
# x = 1:3
# y = sin(x)
# plot(x,y)
# plot(x, y, pch=blablabla) # pch pattern
# plot(x, y, xlab="", ylab="", main="", sub="", xlim=c(xmin,xmax))
# ```
#
# ```
# qplot(x, y, data=df, geom= , xlab='', ylab='', xlim=, ylom=)
# geom='point', 'smooth', 'bar'
# ```
#
# ```
# qplot(x, y, data=df) # xy plot
# qplot(x, y, data=df, geom='path') # xy plot
# qplot(x, y, data=df, colour=z) # xy plot
# qplot(x, y, data=df, size=z) # xy plot
# qplot(factor, x, data=df, fill= , geom='bar') #stacked bar
# xlab('')
# ylab('')
# ```
#
# hist
# ```
# qplot(x, data=df, geom='histgram')
# ```
#
# contour
# ```
# z = matrix(1,5,5)
# z[3,3] = 0
# contour(z)
# ```
#
# persp
# ```
# z = matrix(1,5,5)
# z[3,3] = 0
# persp(z)
# persp(z, expand=0.2)
# ```
#
# ```
# image(z)
# ```
#
# other plotting features
# ```
# abline( h = y )
# abline( v = x )
# abline( line )
# ```
#
# ```
# legend('topright', c('cat', 'dog', 'horse'), pch=1:3)
# ```
#
# ## grammer of graphics
#
# basic structure
#
# ggplot(data=blabla, aes(x=blabla, y=blabla, data=blabla) ) +
# geom_<geom type>( aes(blabla) ) +
# theme()
#
# three ways
# ggplot()
# ggplot()+layer
# ggplot(data)+geom_xx( aes(x=, y=) )
#
# aes is used to assign properties for variables
# aes(x=var1, y=var2, color=var3, shape=, size=, fill=, alpha=)
# BUT if a fixed value is used, put it outside of aes function
# aes(x=var1, y=var2), color='red'
#
# Aesthetics
# x, y, color, shape
#
# histogram
# ggplot(data=data)+
# geom_histogram( aes(x=col1) )
#
# xy
# ggplot(data=data)+
# geom_point( aes=(x=col1, y=col2, color=col3) )
# color can be used to represent different categories OR numeric
#
# ggplot(nmmaps, aes(date, temp, color=factor(season)))+geom_point()
#
# boxplot
# ggplot( data=data )+
# geom_boxplot( aes=(x=col1, y=col2) )
#
# text
# ggplot( data=data )+
# geom_text( aes(x=, y=, label=stringcol), color='red' )
#
#
#
# ggtitle("Corruption and Human development"))
# ggtitle("This is a longer\ntitle than expected")
# g+theme(plot.title = element_text(size=20, face="bold", vjust=1, lineheight=0.6))
# labs(x="Date", y=expression(paste("Temperature ( ", degree ~ F, " )")), title="Temperature")
#
# scale_x_continuous(name = "Corruption Perceptions Index, 2011 (10=least corrupt)",
#                      limits = c(.9, 10.5),
#                      breaks = 1:10)
# scale_y_continuous(name = "Human Development Index, 2011 (1=Best)",
#                      limits = c(0.2, 1.0),
#                      breaks = seq(0.2, 1.0, by = 0.1))
# scale_color_manual(name = "",
#                      values = c("#24576D",
#                                 "#099DD7",
#                                 "#28AADC",
#                                 "#248E84",
#                                 "#F2583F",
#                                 "#96503F"))
#
# theme_minimal()
#
# theme(text = element_text(color = "gray20"),
#         legend.position = c("top"), # position the legend in the upper left
#         legend.direction = "horizontal",
#         legend.justification = 0.1, # anchor point for legend.position.
#         legend.text = element_text(size = 11, color = "gray10"),
#         axis.text = element_text(face = "italic"),
#         axis.title.x = element_text(vjust = -1), # move title away from axis
#         axis.title.y = element_text(vjust = 2), # move away for axis
#         axis.ticks.y = element_blank(), # element_blank() is how we remove elements
#         axis.line = element_line(color = "gray40", size = 0.5),
#         axis.line.y = element_blank(),
#         panel.grid.major = element_line(color = "gray50", size = 0.5),
#         panel.grid.major.x = element_blank()
#         ))
# theme(plot.title = element_text(size=20, face="bold",
#     margin = margin(10, 0, 10, 0)))
# theme(plot.title = element_text(size=30,lineheight=.8,
#   vjust=1,family="Bauhaus 93"))
# theme(axis.ticks.y = element_blank(),axis.text.y = element_blank())
# theme(axis.text.x=element_text(angle=50, size=20, vjust=0.5))
# theme(axis.title.x = element_text(color="forestgreen", vjust=-0.35),
#       axis.title.y = element_text(color="cadetblue" , vjust=0.35)   )
#
# theme(legend.title=element_blank())
# theme(legend.title = element_text(colour="chocolate", size=16, face="bold"))
# ylim(c(0,60))
# theme(legend.title = element_text(colour="chocolate", size=16, face="bold"))+
#   scale_color_discrete(name="This color is\ncalled chocolate!?")
# theme(legend.key=element_rect(fill='pink'))
#
# +facet_wrap(~year, nrow=1)
# facet_grid(year~season)
#
# guides(colour = guide_legend(override.aes = list(size=4)))
#
#
# list packages
# ```
# library()
# ```
#
# Adding Packages
# ```
# install.packages('ggplot2')
# library(ggplot2)
# update.packages()
# remove.packages("thepackagename")
# ```
#
# install R Jupyter notebook
# install.packages('rzmq')
# install.packages(c('repr', 'IRkernel', 'IRdisplay'),
#                  repos = c('http://irkernel.github.io/', getOption('repos')))
# IRkernel::installspec()
#
# # in R 3.2
# IRkernel::installspec(name = 'ir32', displayname = 'R 3.2')
# # in R 3.1
# IRkernel::installspec(name = 'ir31', displayname = 'R 3.1')
#
# -------------------------------------------------------------------------------
#
# Classifier
#
# data(iris)
#
# iris = data.frame( iris,
# is.setosa = ifelse(iris$Species=='setosa', 1, 0),
# is.versicolor = ifelse(iris$Species=='versicolor', 1, 0),
# is.virginica = ifelse(iris$Species=='virginica', 1, 0) )
